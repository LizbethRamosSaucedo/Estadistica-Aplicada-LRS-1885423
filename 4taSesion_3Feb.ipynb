# %% [markdown]
# # Estadistica aplicada
# ## Lizbeth Ramos Saucedo 1885423
# ### 4ta sesion 3 de febrero

# %%
import numpy as np
import pandas as pd

# %%
estadistica_g5 = {'Nombre':['Juan','Jime','Ale'], 'Apellido': ['Rivas', 'Huerta', 'Lopez']}

# %%
estadistica_g5
# Out:
# {'Nombre': ['Juan', 'Jime', 'Ale'], 'Apellido': ['Rivas', 'Huerta', 'Lopez']}

# %%
estadistica_g5= pd.DataFrame ( estadistica_g5)

# %%
estadistica_g5
# Out:
#   Nombre Apellido
# 0   Juan    Rivas
# 1   Jime   Huerta
# 2    Ale    Lopez

# %%
# importar una base de datos de excel  nota: cambiar los diagonales 
pd.read_excel('C:/Users/Lenovo/Documents/N menor a 30.xlsx')
# Out:
#     Se toma una muestra aleatoria de 10 piezas metalicas y se mide la dureza del núcelo en lb. Se desea determinar si la media es 80lb.   \
# 0                                                80.8
# 1                                                81.1
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# ...

# %%
#importar de la nube 
calificaciones = pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/Calificaciones.csv')

# %%
calificaciones.head() #.head sirve para solo ver las primeras 5 observaciones
# Out:
#    Id   Nombre   Apellido  Calficación Final
# 0   1  ANTONIO     GARCIA                 73
# 1   2   MANUEL  FERNANDEZ                 19
# 2   3     JOSE   GONZALEZ                 38
# 3   4    DAVID      PEREZ                 14
# 4   5     JUAN      LOPEZ                 99

# %%
calificaciones.tail()   #para ver las ultimas 5 observaciones
# Out:
#     Id       Nombre   Apellido  Calficación Final
# 23  24         LUIS  DOMINGUEZ                 12
# 24  25      ALBERTO      ORTIZ                 99
# 25  26  JUAN CARLOS     IBAÑEZ                 43
# 26  27       ALVARO    RAMIREZ                 40
# 27  28       ADRIAN       SAEZ                  7

# %%
calificaciones.shape
# Out:
# (28, 4)

# %%
calificaciones.columns
# Out:
# Index(['Id', 'Nombre', 'Apellido', 'Calficación Final'], dtype='object')

# %%
calificaciones.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
calificaciones.dtypes
# Out:
# Id                    int64
# Nombre               object
# Apellido             object
# Calficación Final     int64
# dtype: object

# %%
#correcion de nombre en calificacion final 
calificaciones=calificaciones.rename(columns={'Calficación Final': 'cal_final'})

# %%
calificaciones.head()
# Out:
#    Id   Nombre   Apellido  cal_final
# 0   1  ANTONIO     GARCIA         73
# 1   2   MANUEL  FERNANDEZ         19
# 2   3     JOSE   GONZALEZ         38
# 3   4    DAVID      PEREZ         14
# 4   5     JUAN      LOPEZ         99

# %%
calificaciones['cal_final'].mean()
# Out:
# 52.0

# %%
#funciona como condicion si de excel
calificaciones['situacion']=np.where(calificaciones['cal_final']>=70, 'Aprobado', 'Reprobado')

# %%
calificaciones.head()
# Out:
#    Id   Nombre   Apellido  cal_final  situacion
# 0   1  ANTONIO     GARCIA         73   Aprobado
# 1   2   MANUEL  FERNANDEZ         19  Reprobado
# 2   3     JOSE   GONZALEZ         38  Reprobado
# 3   4    DAVID      PEREZ         14  Reprobado
# 4   5     JUAN      LOPEZ         99   Aprobado

# %%
calificaciones.groupby('situacion').count()
# Out:
#            Id  Nombre  Apellido  cal_final
# situacion
# Aprobado   10      10        10         10
# Reprobado  18      18        18         18

# %%
calificaciones.value_counts('situacion')
# Out:
# situacion
# Reprobado    18
# Aprobado     10
# dtype: int64

# %%
calificaciones.sort_values('cal_final', ascending=False)
# Out:
#     Id            Nombre   Apellido  cal_final  situacion
# 18  19             ANGEL        GIL        100   Aprobado
# 15  16      MIGUEL ANGEL     MORENO        100   Aprobado
# 24  25           ALBERTO      ORTIZ         99   Aprobado
# 4    5              JUAN      LOPEZ         99   Aprobado
# 10  11             JESUS     ALONSO         94   Aprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado
# 14  15            RAFAEL    ALVAREZ         86   Aprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado
# 22  23             JORGE      RAMOS         76   Aprobado
# 0    1           ANTONIO     GARCIA         73   Aprobado
# 5    6      JOSE ANTONIO  RODRIGUEZ         66  Reprobado
# 17  18             PABLO     BLANCO         64  Reprobado
# 9   10            CARLOS       RUIZ         62  Reprobado
# 21  22          FERNANDO    SALAZAR         51  Reprobado
# 6    7            JAVIER    SANCHEZ         46  Reprobado
# ...

# %%
calificaciones.head()
# Out:
#    Id   Nombre   Apellido  cal_final  situacion
# 0   1  ANTONIO     GARCIA         73   Aprobado
# 1   2   MANUEL  FERNANDEZ         19  Reprobado
# 2   3     JOSE   GONZALEZ         38  Reprobado
# 3   4    DAVID      PEREZ         14  Reprobado
# 4   5     JUAN      LOPEZ         99   Aprobado

# %%
premiados = calificaciones[calificaciones['cal_final']>=90]

# %%
premiados.count()
# Out:
# Id           5
# Nombre       5
# Apellido     5
# cal_final    5
# situacion    5
# dtype: int64

# %%
calificaciones.head()
# Out:
#    Id   Nombre   Apellido  cal_final  situacion
# 0   1  ANTONIO     GARCIA         73   Aprobado
# 1   2   MANUEL  FERNANDEZ         19  Reprobado
# 2   3     JOSE   GONZALEZ         38  Reprobado
# 3   4    DAVID      PEREZ         14  Reprobado
# 4   5     JUAN      LOPEZ         99   Aprobado

# %% [markdown]
# #### Tipos de método de selección
# #### 1- selección estandar,
# #### 2-  .iloc (posicion)
# #### 3 -  .loc (etiqueta/nombre)
# #### 4-  metodo
# #### 5-  condicionales

# %%
calificaciones[['Nombre', 'Apellido']]
# Out:
#               Nombre   Apellido
# 0            ANTONIO     GARCIA
# 1             MANUEL  FERNANDEZ
# 2               JOSE   GONZALEZ
# 3              DAVID      PEREZ
# 4               JUAN      LOPEZ
# 5       JOSE ANTONIO  RODRIGUEZ
# 6             JAVIER    SANCHEZ
# 7          JOSE LUIS      GOMEZ
# 8   FRANCISCO JAVIER    JIMENEZ
# 9             CARLOS       RUIZ
# 10             JESUS     ALONSO
# 11         ALEJANDRO  HERNANDEZ
# 12            MIGUEL       DIAZ
# 13       JOSE MANUEL  GUTIERREZ
# 14            RAFAEL    ALVAREZ
# 15      MIGUEL ANGEL     MORENO
# 16             PEDRO      MUÑOZ
# 17             PABLO     BLANCO
# 18             ANGEL        GIL
# 19            SERGIO    AGUIRRE
# 20        JOSE MARIA       DIEZ
# 21          FERNANDO    SALAZAR
# 22             JORGE      RAMOS
# 23              LUIS  DOMINGUEZ
# 24           ALBERTO      ORTIZ
# 25       JUAN CARLOS     IBAÑEZ
# 26            ALVARO    RAMIREZ
# 27            ADRIAN       SAEZ

# %%
calificaciones[0:2]
# Out:
#    Id   Nombre   Apellido  cal_final  situacion
# 0   1  ANTONIO     GARCIA         73   Aprobado
# 1   2   MANUEL  FERNANDEZ         19  Reprobado

# %%
calificaciones[0:2][['Nombre', 'Apellido']]
# Out:
#     Nombre   Apellido
# 0  ANTONIO     GARCIA
# 1   MANUEL  FERNANDEZ

# %%
calificaciones.iloc[:,2]    #posicion fila/ columna   por ejemplo si no elegimos una fila ponemos :
# Out:
# 0        GARCIA
# 1     FERNANDEZ
# 2      GONZALEZ
# 3         PEREZ
# 4         LOPEZ
# 5     RODRIGUEZ
# 6       SANCHEZ
# 7         GOMEZ
# 8       JIMENEZ
# 9          RUIZ
# 10       ALONSO
# 11    HERNANDEZ
# 12         DIAZ
# 13    GUTIERREZ
# 14      ALVAREZ
# 15       MORENO
# 16        MUÑOZ
# 17       BLANCO
# 18          GIL
# 19      AGUIRRE
# 20         DIEZ
# 21      SALAZAR
# 22        RAMOS
# 23    DOMINGUEZ
# 24        ORTIZ
# 25       IBAÑEZ
# 26      RAMIREZ
# 27         SAEZ
# Name: Apellido, dtype: object

# %%
calificaciones.iloc[:2,[1,2]]
# Out:
#     Nombre   Apellido
# 0  ANTONIO     GARCIA
# 1   MANUEL  FERNANDEZ

# %%
calificaciones.loc[:,'Apellido'] #nombre fila/nombre columna
# Out:
# 0        GARCIA
# 1     FERNANDEZ
# 2      GONZALEZ
# 3         PEREZ
# 4         LOPEZ
# 5     RODRIGUEZ
# 6       SANCHEZ
# 7         GOMEZ
# 8       JIMENEZ
# 9          RUIZ
# 10       ALONSO
# 11    HERNANDEZ
# 12         DIAZ
# 13    GUTIERREZ
# 14      ALVAREZ
# 15       MORENO
# 16        MUÑOZ
# 17       BLANCO
# 18          GIL
# 19      AGUIRRE
# 20         DIEZ
# 21      SALAZAR
# 22        RAMOS
# 23    DOMINGUEZ
# 24        ORTIZ
# 25       IBAÑEZ
# 26      RAMIREZ
# 27         SAEZ
# Name: Apellido, dtype: object

# %%
calificaciones.loc[:,['Apellido', 'Nombre']]
# Out:
#      Apellido            Nombre
# 0      GARCIA           ANTONIO
# 1   FERNANDEZ            MANUEL
# 2    GONZALEZ              JOSE
# 3       PEREZ             DAVID
# 4       LOPEZ              JUAN
# 5   RODRIGUEZ      JOSE ANTONIO
# 6     SANCHEZ            JAVIER
# 7       GOMEZ         JOSE LUIS
# 8     JIMENEZ  FRANCISCO JAVIER
# 9        RUIZ            CARLOS
# 10     ALONSO             JESUS
# 11  HERNANDEZ         ALEJANDRO
# 12       DIAZ            MIGUEL
# 13  GUTIERREZ       JOSE MANUEL
# 14    ALVAREZ            RAFAEL
# 15     MORENO      MIGUEL ANGEL
# 16      MUÑOZ             PEDRO
# 17     BLANCO             PABLO
# 18        GIL             ANGEL
# 19    AGUIRRE            SERGIO
# 20       DIEZ        JOSE MARIA
# 21    SALAZAR          FERNANDO
# 22      RAMOS             JORGE
# 23  DOMINGUEZ              LUIS
# 24      ORTIZ           ALBERTO
# 25     IBAÑEZ       JUAN CARLOS
# 26    RAMIREZ            ALVARO
# 27       SAEZ            ADRIAN

# %%
calificaciones.groupby('situacion')['cal_final'].agg(['mean'])    # groupby separa por grupos, si pones mean entre corchetes lo regresa acomodado en data frame
# Out:
#                 mean
# situacion
# Aprobado   90.100000
# Reprobado  30.833333

# %%
calificaciones.groupby('situacion')['cal_final'].agg('mean', 'count','std')
# Out:
# situacion
# Aprobado     90.100000
# Reprobado    30.833333
# Name: cal_final, dtype: float64
